# %%
import os
os.chdir("..")

from heatmap import *

# %% [markdown]
# ## Noise only

# %%
save_name = 'N10_4_A0'
df_test = npy_to_df('precision_A0_n10_4.npy',1)
df_to_heatmap_precision(df_test,1,"(a)",save_name)

save_name = 'N10_A0'
df_test = npy_to_df('precision_A0_n10_full.npy',1)
df_to_heatmap_precision(df_test,1,"(b)",save_name)

save_name = 'N50_A0'
df_test = npy_to_df('precision_A0_n50_full.npy',1)
df_to_heatmap_precision(df_test,1,"(c)",save_name)

save_name = 'N100_A0'
df_test = npy_to_df('precision_A0_n100_full.npy',1)
df_to_heatmap_precision(df_test,1,"(d)",save_name)

# %% [markdown]
# ## CPG ($A=1.8$)

# %%
save_name = 'N10_4_A1point8'
df_test = npy_to_df('precision_A1.8_n10_4.npy',1)
df_to_heatmap_precision(df_test,1,"(a)",save_name)

save_name = 'N10_A1point8'
df_test = npy_to_df('precision_A1.8_n10_full.npy',1)
df_to_heatmap_precision(df_test,1,"(b)",save_name)

save_name = 'N50_A1point8'
df_test = npy_to_df('precision_A1.8_n50_full.npy',1)
df_to_heatmap_precision(df_test,1,"(c)",save_name)

save_name = 'N100_A1point8'
df_test = npy_to_df('precision_A1.8_n100_full.npy',1)
df_to_heatmap_precision(df_test,1,"(d)",save_name)

# %% [markdown]
# ## CPG ($A=3.0$)

# %%
save_name = 'N10_4_A3'
df_test = npy_to_df('precision_A3.0_n10_4.npy',1)
df_to_heatmap_precision(df_test,1,"(a)",save_name)

save_name = 'N10_A3'
df_test = npy_to_df('precision_A3.0_n10_full.npy',1)
df_to_heatmap_precision(df_test,1,"(b)",save_name)

save_name = 'N50_A3'
df_test = npy_to_df('precision_A3.0_n50_full.npy',1)
df_to_heatmap_precision(df_test,1,"(c)",save_name)

save_name = 'N100_A3'
df_test = npy_to_df('precision_A3.0_n100_full.npy',1)
df_to_heatmap_precision(df_test,1,"(d)",save_name)

# %% [markdown]
# ## sin only

# %%
save_name = 'N10_4_D0'
df_test = npy_to_df('precision_D0_n10_4.npy',0)
df_to_heatmap_precision(df_test,0,"(a)",save_name)

save_name = 'N10_D0'
df_test = npy_to_df('precision_D0_n10_full.npy',0)
df_to_heatmap_precision(df_test,0,"(b)",save_name)

save_name = 'N50_D0'
df_test = npy_to_df('precision_D0_n50_full.npy',0)
df_to_heatmap_precision(df_test,0,"(c)",save_name)

save_name = 'N100_D0'
df_test = npy_to_df('precision_D0_n100_full.npy',0)
df_to_heatmap_precision(df_test,0,"(d)",save_name)
